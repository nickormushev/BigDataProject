# %% [markdown]
# # Data augmentation: results

# %%
import pandas as pd

dataset = pd.read_parquet('../datasets/sample_augmented_dataset.parquet')

# %%
# Out:
#        summons_number plate_id registration_state plate_type  \
# 78313      7551971749  FXL4687                 NY        PAS
# 60248      7228388483  GHK7873                 NY        PAS
# 62946      7510733789  GAR2749                 NY        PAS
# 42432      1358176875  EUH4718                 NY        PAS
# 45114      1359793161  14492JY                 NY        COM
# ...               ...      ...                ...        ...
# 85722      9117940874  59286NB                 NY        COM
# 5344       9115987206   C14NYY                 NJ        PAS
# 18981      9116218334  9BFL662                 CA        PAS
# 97114      9118510000  KXP1023                 NY        PAS
# 56259      9117023117  LEK4697                 NY        PAS
#
#                issue_date  violation_code vehicle_body_type vehicle_make  \
# 78313 2013-07-29 21:22:00              38              4DSD        ME/BE
# 60248 2013-07-29 11:57:00              50              4DSD        HONDA
# ...
