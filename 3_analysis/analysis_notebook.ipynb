# %% [markdown]
# ## Analysis
#
# Programmatically perform the introductory exploratory data analysis.
#
# Select and calculate appropriate data aggregates.
#
# Determine and visualize how good your data augmentation is.
#
# When using DuckDB on Parquet files, try to balance between SQL and Dask processing.

# %%
import pandas as pd

# %%
dataset = pd.read_parquet('../datasets/sample_augmented_data.parquet')

# %%
# print every column name and the first 3 items in the column
for column in dataset.columns:
    print(column)
    print(dataset[column].head(3))
    print()
# Out:
# summons_number
# 30356    5069663409
# 87255    7433097510
# 11675    1358115771
# Name: summons_number, dtype: int64
#
# plate_id
# 30356     HSP9388
# 87255    T466979C
# 11675     49722JG
# Name: plate_id, dtype: string
#
# registration_state
# 30356    PA
# 87255    NY
# 11675    NY
# Name: registration_state, dtype: string
#
# plate_type
# 30356    PAS
# 87255    OMT
# 11675    COM
# Name: plate_type, dtype: string
#
# issue_date
# 30356   2013-07-20
# 87255   2013-07-29
# 11675   2013-07-10
# Name: issue_date, dtype: datetime64[ns]
#
# violation_code
# 30356     7
# 87255    21
# 11675    19
# Name: violation_code, dtype: int64
#
# vehicle_body_type
# 30356      CP
# 87255    SUBN
# 11675     VAN
# Name: vehicle_body_type, dtype: string
#
# vehicle_make
# 30356    DODGE
# 87255    TOYOT
# 11675    MAZDA
# Name: vehicle_make, dtype: string
#
# issuing_agency
# 30356    V
# 87255    T
# 11675    X
# Name: issuing_agency, dtype: string
#
# street_code1
# 30356        0
# ...
